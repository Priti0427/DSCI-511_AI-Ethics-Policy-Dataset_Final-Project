# %% [markdown]
# ##  OECD.AI – AI Policy Metadata Collection
#
# In this section, we automatically collect a small sample of AI policy records from the **OECD.AI** policy observatory. The goal is to construct a structured metadata table that can later be combined with other AI ethics and governance sources (e.g., UNESCO, White House OSTP).
#
# The script performs the following steps:
#
# 1. **Set up folders for data storage**
#    - Creates a base directory: `data/policies/`
#    - Creates a subfolder for documents: `data/policies/docs/`
#    These folders will store both the raw OECD CSV file and any downloaded policy documents.
#
# 2. **Download the official OECD AI policies CSV**
#    - Uses the URL:
#      `https://wp.oecd.ai/app/uploads/2024/03/oecd-ai-all-ai-policies.csv`
#    - Sends a polite HTTP request with a custom `User-Agent` for class use.
#    - Saves the file locally as `data/policies/oecd_policies.csv`.
#
# 3. **Load and sample the OECD dataset**
#    - Reads the CSV into a pandas DataFrame.
#    - Selects the **first 3 records** as a small, representative sample for this project phase.
#    - Extracts key metadata fields such as:
#      - `Title`
#      - `Country`
#      - `URL`
#      - `Publication date` (or `Date`)
#
# 4. **Normalize publication dates**
#    - Uses `dateutil.parser` to convert fuzzy date strings into normalized ISO date format (`YYYY-MM-DD`) where possible.
#
# 5. **Build a clean metadata row for each sampled policy**
#    For each record, we construct a standardized dictionary with fields like:
#    - `id` – unique identifier for the policy (e.g., `oecd_0`, `oecd_1`, …)
#    - `title` – policy title from the OECD CSV
#    - `organization` – fixed as `OECD.AI`
#    - `country` – country or region associated with the policy
#    - `url` / `doc_url` – original online location of the policy
#    - `publication_date` – normalized ISO date
#    - `type`, `format`, `language`, `notes`, `local_path` – enriched metadata fields
#
# 6. **Optionally download the policy documents themselves**
#    - For each sampled policy, the script attempts to download the content from `doc_url`.
#    - It inspects the HTTP `Content-Type` or file extension to decide whether to save as `.pdf` or `.html`.
#    - Files are stored under `data/policies/docs/` with safe, sanitized filenames.
#    - The `local_path` field is updated with the path to the saved file.
#
# 7. **Save the final sample dataset as a CSV**
#    - All metadata rows are written to `data/policies/ai_ethics_policies_sample.csv`.
#    - This CSV represents a **reproducible, documented subset** of OECD AI policy metadata that can be merged with other sources in later project phases.
#
# Overall, this scraper is the first building block for our **AI ethics policy dataset**, demonstrating how to responsibly acquire, normalize, and persist public policy data for analysis.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# one time run
import pathlib

# Base directory in the Google Drive
BASE_DIR = pathlib.Path("/content/drive/MyDrive/DSCI-511")
DATA_DIR = BASE_DIR / "data" / "policies"
DOC_DIR = DATA_DIR / "docs"

DATA_DIR.mkdir(parents=True, exist_ok=True)
DOC_DIR.mkdir(parents=True, exist_ok=True)

print("Data directory:", DATA_DIR)
print("Docs directory:", DOC_DIR)
# Out:
# Data directory: /content/drive/MyDrive/DSCI-511/data/policies
# Docs directory: /content/drive/MyDrive/DSCI-511/data/policies/docs

# %%
import os, re, csv, time
import pandas as pd
from datetime import datetime
import requests
from dateutil import parser as dateparser

OUT_CSV = DATA_DIR / "ai_ethics_policies_sample.csv"

def sanitize_filename(s: str) -> str:
    """Make filenames safe for saving."""
    return re.sub(r'[^a-zA-Z0-9._-]+', '_', s)[:120]

def fetch(url, headers=None):
    """Wrapper around GET request with a polite user agent."""
    h = {"User-Agent": "Priti-DSCI-Project/1.0 (class use)"} | (headers or {})
    r = requests.get(url, headers=h, timeout=30)
    r.raise_for_status()
    return r

# 1. OECD AI Policies Data Scraping

rows = []
oecd_csv_url = "https://wp.oecd.ai/app/uploads/2024/03/oecd-ai-all-ai-policies.csv"
try:
    # Fetch and save the CSV
    r = fetch(oecd_csv_url)
    local_csv = DATA_DIR / "oecd_policies.csv"
    local_csv.write_bytes(r.content)
    print("Downloaded OECD policies CSV to:", local_csv)

    # Load CSV
    oecd_df = pd.read_csv(local_csv)

    # Take first 3 records as sample
    for i, rec in oecd_df.head(3).iterrows():
        title = str(rec.get("Title") or rec.get("title") or "OECD Policy")
        country = rec.get("Country") or ""
        url = rec.get("URL") or rec.get("Url") or ""
        pub = rec.get("Publication date") or rec.get("Date") or ""

        # Clean publication date
        pub_dt = ""
        if isinstance(pub, str) and pub.strip():
            try:
                pub_dt = dateparser.parse(pub, fuzzy=True).date().isoformat()
            except Exception:
                pub_dt = ""

        rows.append({
            "id": f"oecd_{i}",
            "title": title,
            "organization": "OECD.AI",
            "country": country,
            "url": url,
            "doc_url": url,
            "publication_date": pub_dt,
            "type": "policy",
            "format": "html" if (isinstance(url, str) and url.lower().endswith(".html")) else "unknown",
            "language": "",
            "notes": "From OECD.AI policies CSV",
            "local_path": ""
        })

except Exception as e:
    print("OECD CSV fetch failed:", e)

# 2. Download OECD documents

for row in rows:
    doc_url = row.get("doc_url")
    if not doc_url or not isinstance(doc_url, str) or not doc_url.strip():
        continue

    try:
        print("Downloading doc:", doc_url)
        rr = fetch(doc_url)

        content_type = rr.headers.get("Content-Type", "").lower()
        is_pdf = content_type.startswith("application/pdf") or doc_url.lower().endswith(".pdf")
        ext = ".pdf" if is_pdf else ".html"

        fname = sanitize_filename(f"{row['id']}_{row['title']}{ext}")
        path = DOC_DIR / fname

        if is_pdf:
            path.write_bytes(rr.content)
        else:
            path.write_text(rr.text, encoding="utf-8", errors="ignore")

        row["local_path"] = str(path)

        time.sleep(0.7)  # polite delay

    except Exception as e:
        print(" Document download failed:", e)
        row["notes"] += f" | download_failed:{e}"

# 3. Save metadata CSV

if rows:
    with open(OUT_CSV, "w", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=list(rows[0].keys()))
        w.writeheader()
        w.writerows(rows)

    print(f"Saved {len(rows)} OECD sample records to {OUT_CSV}")
else:
    print(" No OECD records saved.")
# Out:
# Downloaded OECD policies CSV to: /content/drive/MyDrive/DSCI-511/data/policies/oecd_policies.csv
# Saved 3 OECD sample records to /content/drive/MyDrive/DSCI-511/data/policies/ai_ethics_policies_sample.csv

# %% [markdown]
# ## 🔧 Data Cleaning & Preprocessing
#
# Before merging the OECD dataset, thorough data cleaning was performed to ensure the dataset is accurate, consistent, and suitable for merging with other dataset. Raw data often contains issues such as missing values, duplicated rows, inconsistent data types.
#
# In this section, we walk through the complete data cleaning process, including:
# - Identifying and handling missing values
# - Detecting and removing duplicate records
# - Fixing formatting inconsistencies
# - Handling outliers
# - Engineering clean, reliable features
#
# By the end of this phase, we will have a polished and fully preprocessed dataset that is ready for exploratory analysis.

# %%
# !find "/content/drive/MyDrive" -iname "oecd_policies.csv"
# Out:
# /content/drive/MyDrive/DSCI-511-Project_AI_Ethics_Dataset/DSCI-511/data/policies/oecd_policies.csv
# /content/drive/MyDrive/DSCI-511/data/policies/oecd_policies.csv

# %%
file_path = "/content/drive/MyDrive/DSCI-511/data/policies/oecd_policies.csv"

# %% [markdown]
# ## Analysis of the OECD Data
#
# - Dataset has 1884 rows and 52 columns

# %%
import pandas as pd
df = pd.read_csv(file_path, encoding="utf-8", quotechar='"', low_memory=False)

# Data
print(df.shape)
display(df.head(10))
# Out:
# (1884, 52)
#                 Policy initiative ID  \
# 0   2021/data/policyInitiatives/1335
# 1   2021/data/policyInitiatives/1337
# 2   2021/data/policyInitiatives/1337
# 3   2021/data/policyInitiatives/1355
# 4  2021/data/policyInitiatives/13968
# 5  2021/data/policyInitiatives/13969
# 6  2021/data/policyInitiatives/13969
# 7  2021/data/policyInitiatives/13969
# 8  2021/data/policyInitiatives/14162
# 9  2021/data/policyInitiatives/14162
#
#                                         Platform URL  \
# 0  https://oecd.ai/en/dashboards/policy-initiativ...
# 1  https://oecd.ai/en/dashboards/policy-initiativ...
# 2  https://oecd.ai/en/dashboards/policy-initiativ...
# 3  https://oecd.ai/en/dashboards/policy-initiativ...
# 4  https://oecd.ai/en/dashboards/policy-initiativ...
# 5  https://oecd.ai/en/dashboards/policy-initiativ...
# 6  https://oecd.ai/en/dashboards/policy-initiativ...
# 7  https://oecd.ai/en/dashboards/policy-initiativ...
# 8  https://oecd.ai/en/dashboards/policy-initiativ...
# 9  https://oecd.ai/en/dashboards/policy-initiativ...
#
#                             English name  \
# 0                      SPACERESOURCES.LU
# 1                     DIGITAL LUXEMBOURG
# 2                     DIGITAL LUXEMBOURG
# 3                      DIGITAL TECH FUND
# 4                                GAMEINN
# 5  POLAND-TAIWAN SCIENTIFIC CO-OPERATION
# 6  POLAND-TAIWAN SCIENTIFIC CO-OPERATION
# 7  POLAND-TAIWAN SCIENTIFIC CO-OPERATION
# 8                           AI PROGRAMME
# 9                           AI PROGRAMME
#
#                        Original name(s) Acronym     Country  Start date  \
# 0                                   NaN     NaN  Luxembourg      2016.0
# 1                    Digital Lëtzebuerg     NaN  Luxembourg      2014.0
# 2                    Digital Lëtzebuerg     NaN  Luxembourg      2014.0
# 3                                   NaN     NaN  Luxembourg      2016.0
# 4                                   NaN     NaN      Poland      2016.0
# 5  Polsko-Tajwańska Współpraca Badawcza     NaN      Poland      2012.0
# 6  Polsko-Tajwańska Współpraca Badawcza     NaN      Poland      2012.0
# 7  Polsko-Tajwańska Współpraca Badawcza     NaN      Poland      2012.0
# 8                        Tekoälyohjelma     NaN     Finland      2017.0
# 9                        Tekoälyohjelma     NaN     Finland      2017.0
#
#    End date                                        Description  \
# 0       NaN  Within the SpaceResources.lu initiative, the c...
# 1       NaN  Consolidating Luxembourgs position in the ICT ...
# 2       NaN  Consolidating Luxembourgs position in the ICT ...
# 3       NaN  A seed fund was set up in 2016 jointly by the ...
# 4       NaN  Funding opportunities for the producers of vid...
# 5       NaN  Poland-Taiwan scientific co-operation is based...
# 6       NaN  Poland-Taiwan scientific co-operation is based...
# 7       NaN  Poland-Taiwan scientific co-operation is based...
# 8    2019.0  The AI programme, which published its interim ...
# 9    2019.0  The AI programme, which published its interim ...
#
#           Theme area(s)  ... Objective Deployment year Cancellation reason  \
# 0  National AI Policies  ...       NaN             NaN                 NaN
# 1  National AI Policies  ...       NaN             NaN                 NaN
# 2  National AI Policies  ...       NaN             NaN                 NaN
# 3  National AI Policies  ...       NaN             NaN                 NaN
# 4  National AI Policies  ...       NaN             NaN                 NaN
# 5  National AI Policies  ...       NaN             NaN                 NaN
# 6  National AI Policies  ...       NaN             NaN                 NaN
# 7  National AI Policies  ...       NaN             NaN                 NaN
# 8  National AI Policies  ...       NaN             NaN                 NaN
# 9  National AI Policies  ...       NaN             NaN                 NaN
#
#   Entities involvement Allocated funding  \
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# 5                  NaN               NaN
# 6                  NaN               NaN
# 7                  NaN               NaN
# 8                  NaN               NaN
# 9                  NaN               NaN
#
#   Methodology in place to assess the risk and evaluate the impact of AI in public services  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   Measures taken to communicate the use of the AI system to citizens (transparency)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Measures taken to enable citizens to understand and challenge the outcome of the AI system (explainability and accountability)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Audit, certification, monitoring, evaluation or regulation process  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   Entered into force on
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
#
# [10 rows x 52 columns]

# %%
# last 10 columns
display(df.tail(10))
# Out:
#                   Policy initiative ID  \
# 1874  2021/data/policyInitiatives/4525
# 1875  2021/data/policyInitiatives/4525
# 1876  2021/data/policyInitiatives/4759
# 1877  2021/data/policyInitiatives/4759
# 1878  2021/data/policyInitiatives/4759
# 1879  2021/data/policyInitiatives/4759
# 1880  2021/data/policyInitiatives/5016
# 1881  2021/data/policyInitiatives/5133
# 1882  2021/data/policyInitiatives/5133
# 1883  2021/data/policyInitiatives/5295
#
#                                            Platform URL  \
# 1874  https://oecd.ai/en/dashboards/policy-initiativ...
# 1875  https://oecd.ai/en/dashboards/policy-initiativ...
# 1876  https://oecd.ai/en/dashboards/policy-initiativ...
# 1877  https://oecd.ai/en/dashboards/policy-initiativ...
# 1878  https://oecd.ai/en/dashboards/policy-initiativ...
# 1879  https://oecd.ai/en/dashboards/policy-initiativ...
# 1880  https://oecd.ai/en/dashboards/policy-initiativ...
# 1881  https://oecd.ai/en/dashboards/policy-initiativ...
# 1882  https://oecd.ai/en/dashboards/policy-initiativ...
# 1883  https://oecd.ai/en/dashboards/policy-initiativ...
#
#                                            English name  \
# 1874                                 RESEARCH PLATFORMS
# 1875                                 RESEARCH PLATFORMS
# 1876                                       HORIZON 2020
# 1877                                       HORIZON 2020
# 1878                                       HORIZON 2020
# 1879                                       HORIZON 2020
# 1880                            INNOVATION FUND DENMARK
# 1881                                    ATHENA MAGAZINE
# 1882                                    ATHENA MAGAZINE
# 1883  AI R&D FRAMEWORK AND ACTIVITIES OF THE ISRAELI...
#
#                                        Original name(s) Acronym  \
# 1874                                                NaN     NaN
# 1875                                                NaN     NaN
# 1876                                                NaN   H2020
# 1877                                                NaN   H2020
# 1878                                                NaN   H2020
# 1879                                                NaN   H2020
# 1880                                  INNOVATIONSFONDEN     NaN
# 1881                                                NaN     NaN
# 1882                                                NaN     NaN
# 1883  מסגרת פעילות של רשות החדשנות בתחומי בינה מלאכותית  IIA_AI
#
#              Country  Start date  End date  \
# 1874         Belgium      2010.0       NaN
# 1875         Belgium      2010.0       NaN
# 1876  European Union      2014.0    2020.0
# 1877  European Union      2014.0    2020.0
# 1878  European Union      2014.0    2020.0
# 1879  European Union      2014.0    2020.0
# 1880         Denmark      2014.0       NaN
# 1881         Belgium      1984.0       NaN
# 1882         Belgium      1984.0       NaN
# 1883          Israel      2019.0       NaN
#
#                                             Description         Theme area(s)  \
# 1874  The program Research platforms, a program prev...  National AI Policies
# 1875  The program Research platforms, a program prev...  National AI Policies
# 1876  The EU framework programme for Research and In...  National AI Policies
# 1877  The EU framework programme for Research and In...  National AI Policies
# 1878  The EU framework programme for Research and In...  National AI Policies
# 1879  The EU framework programme for Research and In...  National AI Policies
# 1880  Innovation Fund Denmark is the main public fun...  National AI Policies
# 1881  Publication of a free monthly magazine “Athena...  National AI Policies
# 1882  Publication of a free monthly magazine “Athena...  National AI Policies
# 1883  The Planned AI R&D Framework & Activities in p...  National AI Policies
#
#       ... Objective Deployment year Cancellation reason Entities involvement  \
# 1874  ...       NaN             NaN                 NaN                  NaN
# 1875  ...       NaN             NaN                 NaN                  NaN
# 1876  ...       NaN             NaN                 NaN                  NaN
# 1877  ...       NaN             NaN                 NaN                  NaN
# 1878  ...       NaN             NaN                 NaN                  NaN
# 1879  ...       NaN             NaN                 NaN                  NaN
# 1880  ...       NaN             NaN                 NaN                  NaN
# 1881  ...       NaN             NaN                 NaN                  NaN
# 1882  ...       NaN             NaN                 NaN                  NaN
# 1883  ...       NaN             NaN                 NaN                  NaN
#
#      Allocated funding  \
# 1874               NaN
# 1875               NaN
# 1876               NaN
# 1877               NaN
# 1878               NaN
# 1879               NaN
# 1880               NaN
# 1881               NaN
# 1882               NaN
# 1883               NaN
#
#      Methodology in place to assess the risk and evaluate the impact of AI in public services  \
# 1874                                                NaN
# 1875                                                NaN
# 1876                                                NaN
# 1877                                                NaN
# 1878                                                NaN
# 1879                                                NaN
# 1880                                                NaN
# 1881                                                NaN
# 1882                                                NaN
# 1883                                                NaN
#
#      Measures taken to communicate the use of the AI system to citizens (transparency)  \
# 1874                                                NaN
# 1875                                                NaN
# 1876                                                NaN
# 1877                                                NaN
# 1878                                                NaN
# 1879                                                NaN
# 1880                                                NaN
# 1881                                                NaN
# 1882                                                NaN
# 1883                                                NaN
#
#       Measures taken to enable citizens to understand and challenge the outcome of the AI system (explainability and accountability)  \
# 1874                                                NaN
# 1875                                                NaN
# 1876                                                NaN
# 1877                                                NaN
# 1878                                                NaN
# 1879                                                NaN
# 1880                                                NaN
# 1881                                                NaN
# 1882                                                NaN
# 1883                                                NaN
#
#       Audit, certification, monitoring, evaluation or regulation process  \
# 1874                                                NaN
# 1875                                                NaN
# 1876                                                NaN
# 1877                                                NaN
# 1878                                                NaN
# 1879                                                NaN
# 1880                                                NaN
# 1881                                                NaN
# 1882                                                NaN
# 1883                                                NaN
#
#      Entered into force on
# 1874                   NaN
# 1875                   NaN
# 1876                   NaN
# 1877                   NaN
# 1878                   NaN
# 1879                   NaN
# 1880                   NaN
# 1881                   NaN
# 1882                   NaN
# 1883                   NaN
#
# [10 rows x 52 columns]

# %% [markdown]
# - Understanding the Data columns(like Description)
#
# In this step, we examine a subset of the **Description** column from our dataset.

# %%
display(df['Description'][1:10])
# Out:
# 1    Consolidating Luxembourgs position in the ICT ...
# 2    Consolidating Luxembourgs position in the ICT ...
# 3    A seed fund was set up in 2016 jointly by the ...
# 4    Funding opportunities for the producers of vid...
# 5    Poland-Taiwan scientific co-operation is based...
# 6    Poland-Taiwan scientific co-operation is based...
# 7    Poland-Taiwan scientific co-operation is based...
# 8    The AI programme, which published its interim ...
# 9    The AI programme, which published its interim ...
# Name: Description, dtype: object

# %%
# for examining the long text in 'description' column
import pandas as pd
from IPython.display import display

with pd.option_context('display.max_colwidth', None):
    display(df['Description'].iloc[1:10])
# Out:
# 1                                                                                                                                                                                                                                                                                                               Consolidating Luxembourgs position in the ICT fields in the longer term.
# 2                                                                                                                                                                                                                                                                                                               Consolidating Luxembourgs position in the ICT fields in the longer term.
# 3                                                                                                                                                                                                                                                                                    A seed fund was set up in 2016 jointly by the Ministry of Economy and a group of private investors.
# 4                                                                                                                                                                                                                      Funding opportunities for the producers of video games (the thematic scope of the programme comprises the application of Artificial Intelligence in video games).
# 5    Poland-Taiwan scientific co-operation is based on the agreement between the National Centre for Research and Development and the Ministry of Science and Technology of the Republic of China (originally established as the National Science Council of Taiwan) and consists in joint funding of scientific and R&D projects and organisation of scientific seminars, among others.
# 6    Poland-Taiwan scientific co-operation is based on the agreement between the National Centre for Research and Development and the Ministry of Science and Technology of the Republic of China (originally established as the National Science Council of Taiwan) and consists in joint funding of scientific and R&D projects and organisation of scientific seminars, among others.
# 7    Poland-Taiwan scientific co-operation is based on the agreement between the National Centre for Research and Development and the Ministry of Science and Technology of the Republic of China (originally established as the National Science Council of Taiwan) and consists in joint funding of scientific and R&D projects and organisation of scientific seminars, among others.
# 8                                                                                                                                                                             The AI programme, which published its interim report with eight proposals in October 2017 and final report in 2019, steered Finland into the track of becoming a leading country in the application of AI.
# 9                                                                                                                                                                             The AI programme, which published its interim report with eight proposals in October 2017 and final report in 2019, steered Finland into the track of becoming a leading country in the application of AI.
# Name: Description, dtype: object

# %% [markdown]
# ### Checking Missing Values in the Dataset
#
# Before performing any analysis, it is important to understand how much data is missing in each column.
# - This step calculates and summarizes the number and percentage of missing values across the dataset.
#
# - This summary helps identify columns that may require imputation, removal, or further investigation.

# %%
nan_counts = df.isna().sum()
nan_percent = (nan_counts / len(df)) * 100

missing_summary = pd.DataFrame({
    'Missing Count': nan_counts,
    'Missing %': nan_percent.round(2)
}).sort_values(by='Missing %', ascending=False)

print(f"Total rows: {len(df)}\n")
missing_summary
# Out:
# Total rows: 1884
#                                                     Missing Count  Missing %
# Measures taken to enable citizens to understand...           1880      99.79
# Budget amount\n(in local currency)                           1879      99.73
# Methodology in place to assess the risk and eva...           1879      99.73
# Cancellation reason                                          1875      99.52
# Consultation process end date                                1872      99.36
# Audit, certification, monitoring, evaluation or...           1872      99.36
# Allocated funding                                            1871      99.31
# Consultation process objective                               1869      99.20
# Other AI Policy Area(s)                                      1866      99.04
# Consultation process begin date                              1866      99.04
# Coordinating institution name                                1864      98.94
# Entities involvement                                         1861      98.78
# Measures taken to communicate the use of the AI...           1861      98.78
# Shift(s) related to Covid                                    1848      98.09
# Entered into force on                                        1842      97.77
# Strategy priority targets and deadlines                      1836      97.45
# Deployment year                                              1836      97.45
# Evaluation provides input to                                 1826      96.92
# Evaluation type                                              1815      96.34
# Objective                                                    1814      96.28
# Evaluation performed by                                      1813      96.23
# Evaluation URL                                               1801      95.59
# Link                                                         1453      77.12
# End date                                                     1418      75.27
# Policy instrument description(s)                             1384      73.46
# Acronym                                                      1355      71.92
# Policy instrument name                                       1025      54.41
# Original name(s)                                              899      47.72
# Background                                                    733      38.91
# Policy instrument mini-field(s)                               533      28.29
# Public access URL                                             338      17.94
# AI Policy Area(s)                                             329      17.46
# AI Principle(s)                                               139       7.38
# Responsible organisation(s)                                    91       4.83
# Target group type(s)                                           58       3.08
# Target group(s)                                                58       3.08
# Start date                                                     54       2.87
# Objective(s)                                                   53       2.81
# Policy instrument type                                         47       2.49
# Policy instrument type category                                47       2.49
# Description                                                    30       1.59
# English name                                                    1       0.05
# Platform URL                                                    0       0.00
# Policy initiative ID                                            0       0.00
# Has funding from private sector ?                               0       0.00
# Yearly budget range                                             0       0.00
# Theme area(s)                                                   0       0.00
# Theme(s)                                                        0       0.00
# Country                                                         0       0.00
# Policy instrument ID                                            0       0.00
# Is a structural reform ?                                        0       0.00
# Is evaluated ?                                                  0       0.00

# %% [markdown]
# - The missing-data percentages show that most AI ethics policies include high-level elements like transparency, explainability, citizen rights, and risk assessment. However, large portions of practical information are missing such as awareness plans, responsible organizations, target groups, implementation details, and yearly funding plans. This suggests that while countries focus on ethical principles, many policies still lack concrete execution, budgeting, and public-engagement strategies.

# %% [markdown]
# - AI Ethics Policies with Start date as 2024

# %%
df[df['Start date'] == 2024]
# Out:
#                    Policy initiative ID  \
# 1818  2021/data/policyInitiatives/27588
# 1819  2021/data/policyInitiatives/27588
# 1820  2021/data/policyInitiatives/27588
# 1821  2021/data/policyInitiatives/27588
# 1822  2021/data/policyInitiatives/27589
# 1853  2021/data/policyInitiatives/27618
# 1854  2021/data/policyInitiatives/27619
# 1855  2021/data/policyInitiatives/27620
# 1856  2021/data/policyInitiatives/27621
#
#                                            Platform URL  \
# 1818  https://oecd.ai/en/dashboards/policy-initiativ...
# 1819  https://oecd.ai/en/dashboards/policy-initiativ...
# 1820  https://oecd.ai/en/dashboards/policy-initiativ...
# 1821  https://oecd.ai/en/dashboards/policy-initiativ...
# 1822  https://oecd.ai/en/dashboards/policy-initiativ...
# 1853  https://oecd.ai/en/dashboards/policy-initiativ...
# 1854  https://oecd.ai/en/dashboards/policy-initiativ...
# 1855  https://oecd.ai/en/dashboards/policy-initiativ...
# 1856  https://oecd.ai/en/dashboards/policy-initiativ...
#
#                                            English name  \
# 1818  AI INNOVATION PACKAGE TO SUPPORT ATIFICIAL INT...
# 1819  AI INNOVATION PACKAGE TO SUPPORT ATIFICIAL INT...
# 1820  AI INNOVATION PACKAGE TO SUPPORT ATIFICIAL INT...
# 1821  AI INNOVATION PACKAGE TO SUPPORT ATIFICIAL INT...
# 1822  NATIONAL ARTIFICIAL INTELLIGENCE RESEARCH RESO...
# 1853  Open-source artificial intelligence algorithm ...
# 1854  Technological sandbox on the use of exponentia...
# 1855  Continuous Artificial Intelligence Program for...
# 1856  Public-private regulatory sandbox regarding th...
#
#                                        Original name(s) Acronym  \
# 1818                                                NaN     NaN
# 1819                                                NaN     NaN
# 1820                                                NaN     NaN
# 1821                                                NaN     NaN
# 1822                                                NaN   NAIRR
# 1853  Servicio de algoritmos de inteligencia artific...     NaN
# 1854  Sandbox tecnológico sobre uso de tecnologías e...     NaN
# 1855  Programa de Inteligencia Artificial de manera ...     NaN
# 1856  Sandbox regulatorio público-privado respecto a...     NaN
#
#              Country  Start date  End date  \
# 1818  European Union      2024.0       NaN
# 1819  European Union      2024.0       NaN
# 1820  European Union      2024.0       NaN
# 1821  European Union      2024.0       NaN
# 1822   United States      2024.0    2026.0
# 1853            Peru      2024.0       NaN
# 1854            Peru      2024.0       NaN
# 1855            Peru      2024.0       NaN
# 1856            Peru      2024.0       NaN
#
#                                             Description         Theme area(s)  \
# 1818  The Commission has launched a package of measu...  National AI Policies
# 1819  The Commission has launched a package of measu...  National AI Policies
# 1820  The Commission has launched a package of measu...  National AI Policies
# 1821  The Commission has launched a package of measu...  National AI Policies
# 1822  The NAIRR pilot brings together computational,...  National AI Policies
# 1853  Continuous service enabled for public institut...  National AI Policies
# 1854  Use of technologies that allow massive process...  National AI Policies
# 1855  The program includes the diagnosis and design ...  National AI Policies
# 1856  The project covers: improving the integration ...  National AI Policies
#
#       ... Objective Deployment year Cancellation reason Entities involvement  \
# 1818  ...       NaN             NaN                 NaN                  NaN
# 1819  ...       NaN             NaN                 NaN                  NaN
# 1820  ...       NaN             NaN                 NaN                  NaN
# 1821  ...       NaN             NaN                 NaN                  NaN
# 1822  ...       NaN             NaN                 NaN                  NaN
# 1853  ...       NaN             NaN                 NaN                  NaN
# 1854  ...       NaN             NaN                 NaN                  NaN
# 1855  ...       NaN             NaN                 NaN                  NaN
# 1856  ...       NaN             NaN                 NaN                  NaN
#
#      Allocated funding  \
# 1818               NaN
# 1819               NaN
# 1820               NaN
# 1821               NaN
# 1822               NaN
# 1853               NaN
# 1854               NaN
# 1855               NaN
# 1856               NaN
#
#      Methodology in place to assess the risk and evaluate the impact of AI in public services  \
# 1818                                                NaN
# 1819                                                NaN
# 1820                                                NaN
# 1821                                                NaN
# 1822                                                NaN
# 1853                                                NaN
# 1854                                                NaN
# 1855                                                NaN
# 1856                                                NaN
#
#      Measures taken to communicate the use of the AI system to citizens (transparency)  \
# 1818                                                NaN
# 1819                                                NaN
# 1820                                                NaN
# 1821                                                NaN
# 1822                                                NaN
# 1853                                                NaN
# 1854                                                NaN
# 1855                                                NaN
# 1856                                                NaN
#
#       Measures taken to enable citizens to understand and challenge the outcome of the AI system (explainability and accountability)  \
# 1818                                                NaN
# 1819                                                NaN
# 1820                                                NaN
# 1821                                                NaN
# 1822                                                NaN
# 1853                                                NaN
# 1854                                                NaN
# 1855                                                NaN
# 1856                                                NaN
#
#       Audit, certification, monitoring, evaluation or regulation process  \
# 1818                                                NaN
# 1819                                                NaN
# 1820                                                NaN
# 1821                                                NaN
# 1822                                                NaN
# 1853                                                NaN
# 1854                                                NaN
# 1855                                                NaN
# 1856                                                NaN
#
#      Entered into force on
# 1818                   NaN
# 1819                   NaN
# 1820                   NaN
# 1821                   NaN
# 1822                   NaN
# 1853                   NaN
# 1854                   NaN
# 1855                   NaN
# 1856                   NaN
#
# [9 rows x 52 columns]

# %% [markdown]
# - We can Drop columns with more than 60% missing values(this is the criteria we used to have the columns, which can help in further analysis and modeling)
#
# - Columns with too many missing values provide little useful information, so we remove any column where more than 60% of entries are missing.

# %%
# Drop columns having more than 60% missing data
missing_threshold = 60  # percent(we can change this according to the use case)
cols_to_drop = missing_summary[missing_summary["Missing %"] > missing_threshold].index.tolist()

df_clean = df.drop(columns=cols_to_drop)

print("Dropped Columns:", len(cols_to_drop))
cols_to_drop
# Out:
# Dropped Columns: 26
# ['Measures taken to enable citizens to understand and challenge the outcome of the AI system (explainability and accountability)',
#  'Budget amount\n(in local currency)',
#  'Methodology in place to assess the risk and evaluate the impact of AI in public services',
#  'Cancellation reason',
#  'Consultation process end date',
#  'Audit, certification, monitoring, evaluation or regulation process',
#  'Allocated funding',
#  'Consultation process objective',
#  'Other AI Policy Area(s)',
#  'Consultation process begin date',
#  'Coordinating institution name',
#  'Entities involvement',
#  'Measures taken to communicate the use of the AI system to citizens (transparency)',
#  'Shift(s) related to Covid',
#  'Entered into force on',
#  'Strategy priority targets and deadlines',
#  'Deployment year',
#  'Evaluation provides input to',
#  'Evaluation type',
#  'Objective',
#  'Evaluation performed by',
#  'Evaluation URL',
#  'Link',
#  'End date',
#  'Policy instrument description(s)',
#  'Acronym']

# %% [markdown]
# ### Handling missing values in text columns
#
# - For text/object columns, missing entries are replaced with "Unknown" so that the dataset remains usable without introducing errors.

# %%
text_cols = df_clean.select_dtypes(include=["object"]).columns
df_clean[text_cols] = df_clean[text_cols].fillna("Unknown")

# %% [markdown]
# ### Handling missing values in numeric columns
#
# - Numeric columns cannot contain NaN for machine learning, so we fill missing values using column "means" to preserve dataset structure.

# %%
# Select all object/text columns that actually exist
text_cols = df_clean.select_dtypes(include=["object"]).columns.tolist()

print("Text columns:", text_cols)

# Fill NaN only in these columns
df_clean[text_cols] = df_clean[text_cols].fillna("Unknown")
# Out:
# Text columns: ['Policy initiative ID', 'Platform URL', 'English name', 'Original name(s)', 'Country', 'Description', 'Theme area(s)', 'Theme(s)', 'Background', 'Objective(s)', 'Target group type(s)', 'Target group(s)', 'Responsible organisation(s)', 'Yearly budget range', 'Public access URL', 'AI Principle(s)', 'AI Policy Area(s)', 'Policy instrument ID', 'Policy instrument type category', 'Policy instrument type', 'Policy instrument name', 'Policy instrument mini-field(s)']

# %% [markdown]
# ### Fill missing numeric values using column means
#
# - Numeric columns cannot contain NaN during analysis or model training, so we replace missing numeric values with the mean of each column to maintain consistency without losing rows.

# %%
num_cols = df_clean.select_dtypes(include=["number"]).columns.tolist()

df_clean[num_cols] = df_clean[num_cols].fillna(df_clean[num_cols].mean())

# %% [markdown]
# ### Save the cleaned dataset
#
# - We export the fully cleaned DataFrame as oecd_policies_clean.csv
# so it can be reused for future analysis and modeling without repeating the cleaning steps.
# - Now, there are 26 columns in the Dataset.

# %%
df_clean.to_csv("/content/drive/MyDrive/DSCI-511/data/policies/oecd_policies_clean.csv",
                index=False)

# %%
df_clean = pd.read_csv("/content/drive/MyDrive/DSCI-511/data/policies/oecd_policies_clean.csv")
df_clean.head()
# Out:
#                 Policy initiative ID  \
# 0   2021/data/policyInitiatives/1335
# 1   2021/data/policyInitiatives/1337
# 2   2021/data/policyInitiatives/1337
# 3   2021/data/policyInitiatives/1355
# 4  2021/data/policyInitiatives/13968
#
#                                         Platform URL        English name  \
# 0  https://oecd.ai/en/dashboards/policy-initiativ...   SPACERESOURCES.LU
# 1  https://oecd.ai/en/dashboards/policy-initiativ...  DIGITAL LUXEMBOURG
# 2  https://oecd.ai/en/dashboards/policy-initiativ...  DIGITAL LUXEMBOURG
# 3  https://oecd.ai/en/dashboards/policy-initiativ...   DIGITAL TECH FUND
# 4  https://oecd.ai/en/dashboards/policy-initiativ...             GAMEINN
#
#      Original name(s)     Country  Start date  \
# 0             Unknown  Luxembourg      2016.0
# 1  Digital Lëtzebuerg  Luxembourg      2014.0
# 2  Digital Lëtzebuerg  Luxembourg      2014.0
# 3             Unknown  Luxembourg      2016.0
# 4             Unknown      Poland      2016.0
#
#                                          Description         Theme area(s)  \
# 0  Within the SpaceResources.lu initiative, the c...  National AI Policies
# 1  Consolidating Luxembourgs position in the ICT ...  National AI Policies
# 2  Consolidating Luxembourgs position in the ICT ...  National AI Policies
# 3  A seed fund was set up in 2016 jointly by the ...  National AI Policies
# 4  Funding opportunities for the producers of vid...  National AI Policies
#
#                Theme(s)                                         Background  \
# 0  National AI policies  Luxembourg provides a unique legal, regulatory...
# 1  National AI policies  Over the past ten years, Luxembourg’s digital ...
# 2  National AI policies  Over the past ten years, Luxembourg’s digital ...
# 3  National AI policies  This fund is part of the strategy Digital Lëtz...
# 4  National AI policies                                            Unknown
#
#    ...                                  Public access URL  \
# 0  ...        http://www.spaceresources.public.lu/en.html
# 1  ...  https://gouvernement.lu/en/dossiers/2014/digit...
# 2  ...  https://gouvernement.lu/en/dossiers/2014/digit...
# 3  ...  https://digital-luxembourg.public.lu/initiativ...
# 4  ...  http://www.ncbr.gov.pl/en/news/art,4200,playin...
#
#   Is a structural reform ? Is evaluated ?  \
# 0                    False          False
# 1                    False           True
# 2                    False           True
# 3                    False          False
# 4                    False          False
#
#                                      AI Principle(s) AI Policy Area(s)  \
# 0  Fostering a digital ecosystem for AI|Investing...           Unknown
# 1  Inclusive growth, sustainable development and ...           Unknown
# 2  Inclusive growth, sustainable development and ...           Unknown
# 3               Fostering a digital ecosystem for AI           Unknown
# 4                                            Unknown           Unknown
#
#                                 Policy instrument ID  \
# 0  http://aipo.oecd.org/2021/data/policyInitiativ...
# 1  http://aipo.oecd.org/2021/data/policyInitiativ...
# 2  http://aipo.oecd.org/2021/data/policyInitiativ...
# 3  http://aipo.oecd.org/2021/data/policyInitiativ...
# 4  http://aipo.oecd.org/2021/data/policyInitiativ...
#
#     Policy instrument type category                  Policy instrument type  \
# 0                        Governance  National strategies, agendas and plans
# 1  AI enablers and other incentives  Networking and collaborative platforms
# 2                        Governance  National strategies, agendas and plans
# 3                 Financial support                        Equity financing
# 4                 Financial support  Grants for business R&D and innovation
#
#    Policy instrument name                    Policy instrument mini-field(s)
# 0                 Unknown  Societal challenge(s) emphasised: None specifi...
# 1                 Unknown                                            Unknown
# 2                 Unknown  Implementation mechanism: Periodic monitoring ...
# 3                 Unknown  Focus: Other\nMechanism(s): Fund\nType of fina...
# 4                 Unknown  Contribution (e.g. matching funds) required fr...
#
# [5 rows x 26 columns]

# %%
df_clean.dtypes
# Out:
# Policy initiative ID                  object
# Platform URL                          object
# English name                          object
# Original name(s)                      object
# Country                               object
# Start date                           float64
# Description                           object
# Theme area(s)                         object
# Theme(s)                              object
# Background                            object
# Objective(s)                          object
# Target group type(s)                  object
# Target group(s)                       object
# Responsible organisation(s)           object
# Yearly budget range                   object
# Has funding from private sector ?       bool
# Public access URL                     object
# Is a structural reform ?                bool
# Is evaluated ?                          bool
# AI Principle(s)                       object
# AI Policy Area(s)                     object
# Policy instrument ID                  object
# Policy instrument type category       object
# Policy instrument type                object
# Policy instrument name                object
# Policy instrument mini-field(s)       object
# dtype: object

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Policy initiative ID               1884 non-null   object
#  1   Platform URL                       1884 non-null   object
#  2   English name                       1884 non-null   object
#  3   Original name(s)                   1884 non-null   object
#  4   Country                            1884 non-null   object
#  5   Start date                         1884 non-null   float64
#  6   Description                        1884 non-null   object
#  7   Theme area(s)                      1884 non-null   object
#  8   Theme(s)                           1884 non-null   object
#  9   Background                         1884 non-null   object
#  10  Objective(s)                       1884 non-null   object
#  11  Target group type(s)               1884 non-null   object
#  12  Target group(s)                    1884 non-null   object
#  13  Responsible organisation(s)        1884 non-null   object
#  14  Yearly budget range                1884 non-null   object
#  15  Has funding from private sector ?  1884 non-null   bool
#  16  Public access URL                  1884 non-null   object
#  17  Is a structural reform ?           1884 non-null   bool
#  18  Is evaluated ?                     1884 non-null   bool
#  19  AI Principle(s)                    1884 non-null   object
#  20  AI Policy Area(s)                  1884 non-null   object
#  21  Policy instrument ID               1884 non-null   object
#  22  Policy instrument type category    1884 non-null   object
#  23  Policy instrument type             1884 non-null   object
#  24  Policy instrument name             1884 non-null   object
#  25  Policy instrument mini-field(s)    1884 non-null   object
# dtypes: bool(3), float64(1), object(22)
# memory usage: 344.2+ KB

# %% [markdown]
# For further analysis, some columns should be converted to more suitable dtypes:
#
# - We should Convert Start date from float64 to datetime (e.g., pd.to_datetime(df_clean["Start date"], errors="coerce")) for time-based analysis.
#
# - We should Keep bollean  as Boolean for logical filtering and grouping.
#
# - We should Keep ID fields (Policy initiative ID, Policy instrument ID) as integers or categorical, not numeric measures.
#
# - We should  convert high-cardinality text descriptors (e.g., Country, AI Policy Area(s), Theme area(s), Policy instrument type) to category dtype to save memory and improve groupby operations.

# %% [markdown]
# ### Locate the cleaned dataset in Google Drive
#
# - We search through the Drive directory to confirm where the cleaned oecd_policies_clean.csv file is saved and verify that it was written correctly.

# %%
import os

for root, dirs, files in os.walk("/content/drive/MyDrive", topdown=True):
    for f in files:
        if "oecd_policies_clean" in f.lower():
            print(os.path.join(root, f))
# Out:
# /content/drive/MyDrive/DSCI-511-Project_AI_Ethics_Dataset/DSCI-511/data/policies/oecd_policies_clean.csv
# /content/drive/MyDrive/DSCI-511/data/policies/oecd_policies_clean.csv

# %%
print("Files in /content/drive/MyDrive/DSCI-511/data/policies:")
import os
print(os.listdir("/content/drive/MyDrive/DSCI-511/data/policies"))
# Out:
# Files in /content/drive/MyDrive/DSCI-511/data/policies:
# ['docs', 'oecd_policies.csv', 'ai_ethics_policies_sample.csv', 'oecd_policies_clean.csv']

# %% [markdown]
# ### Reload the cleaned dataset and verify missing values
# - Loading the cleaned CSV file and generate a new missing-value summary to confirm that all missing data has been properly handled after the cleaning process.

# %%
df_clean = pd.read_csv(
    "/content/drive/MyDrive/DSCI-511/data/policies/oecd_policies_clean.csv"
)

nan_counts_clean = df_clean.isna().sum()
nan_percent_clean = (nan_counts_clean / len(df_clean)) * 100

missing_summary_clean = pd.DataFrame({
    "Missing Count": nan_counts_clean,
    "Missing %": nan_percent_clean
}).sort_values(by="Missing %", ascending=False)

display(missing_summary_clean)
# Out:
#                                    Missing Count  Missing %
# Policy initiative ID                           0        0.0
# Platform URL                                   0        0.0
# English name                                   0        0.0
# Original name(s)                               0        0.0
# Country                                        0        0.0
# Start date                                     0        0.0
# Description                                    0        0.0
# Theme area(s)                                  0        0.0
# Theme(s)                                       0        0.0
# Background                                     0        0.0
# Objective(s)                                   0        0.0
# Target group type(s)                           0        0.0
# Target group(s)                                0        0.0
# Responsible organisation(s)                    0        0.0
# Yearly budget range                            0        0.0
# Has funding from private sector ?              0        0.0
# Public access URL                              0        0.0
# Is a structural reform ?                       0        0.0
# Is evaluated ?                                 0        0.0
# AI Principle(s)                                0        0.0
# AI Policy Area(s)                              0        0.0
# Policy instrument ID                           0        0.0
# Policy instrument type category                0        0.0
# Policy instrument type                         0        0.0
# Policy instrument name                         0        0.0
# Policy instrument mini-field(s)                0        0.0

# %% [markdown]
# ### Conclusion:
# This is first part of our Project . Now, we need to scrap two more websites to enrich this Dataset.
